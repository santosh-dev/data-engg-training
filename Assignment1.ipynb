# %%
import pandas as pd

scmDF = pd.read_csv('supply_chain_data.csv')
scmDF.head(20)
scmDF.tail()
#scmDF.describe()

scmDF.sort_values("Availability").head(10)

scmDF.sort_values("Availability",ascending=False).head(10)

scmDF["Product type"].value_counts()

scmDF[(scmDF["Product type"] == "skincare") & (scmDF["Availability"] > 50)].head(10)


scmDF[scmDF["Number of products sold"].isna()]

#scmDF.dropna(subset=["Number of products sold"], inplace=True) # Remove rows with missing values

#scmDF ["Price"].fillna(10, inplace=True) # Fill missing values with default value as 10 to price column

scmDF.rename(columns={'Number of products sold':'Sold Count'},inplace=True)

scmDF.head()
# Out:
#   Product type   SKU      Price  Availability  Sold Count  Revenue generated  \
# 0     haircare  SKU0  69.808006            55         802        8661.996792
# 1     skincare  SKU1  14.843523            95         736        7460.900065
# 2     haircare  SKU2  11.319683            34           8        9577.749626
# 3     skincare  SKU3  61.163343            68          83        7766.836426
# 4     skincare  SKU4   4.805496            26         871        2686.505152
#
#   Customer demographics  Stock levels  Lead times  Order quantities  ...  \
# 0            Non-binary            58           7                96  ...
# 1                Female            53          30                37  ...
# 2               Unknown             1          10                88  ...
# 3            Non-binary            23          13                59  ...
# 4            Non-binary             5           3                56  ...
#
#    Location Lead time  Production volumes Manufacturing lead time  \
# 0    Mumbai        29                 215                      29
# 1    Mumbai        23                 517                      30
# 2    Mumbai        12                 971                      27
# 3   Kolkata        24                 937                      18
# 4     Delhi         5                 414                       3
#
#   Manufacturing costs  Inspection results  Defect rates  Transportation modes  \
# 0           46.279879             Pending      0.226410                  Road
# 1           33.616769             Pending      4.854068                  Road
# 2           30.688019             Pending      4.580593                   Air
# 3           35.624741                Fail      4.746649                  Rail
# 4           92.065161                Fail      3.145580                   Air
#
#     Routes       Costs
# 0  Route B  187.752075
# 1  Route B  503.065579
# 2  Route C  141.920282
# 3  Route A  254.776159
# 4  Route A  923.440632
#
# [5 rows x 24 columns]
