# %%
pip install matplotlib

# %%
import pandas as pd

custdf=pd.read_csv('Customer-Churn-Records.csv')

display(custdf)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
import matplotlib.pyplot as mp

custdf.boxplot('Age')
mp.show()

# %%
custdf.plot(kind='bar',y='Age')
mp.show()

# %%
custdf.plot(kind='bar',y='Age')
#mp.show()

mp.savefig('bar-chart.pdf',format='pdf')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 custdf.plot(kind='bar',y='Age')
#       2 #mp.show()
#       4 mp.savefig('bar-chart.pdf',format='pdf')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
#display function is slower and takes more memory insteaad we can use print

print(custdf.to_string)

# %%
custdf.plot(kind='line',y='Age')
mp.show()

# %%
# create 2D array of table given above
data = [['E001', 'M', 34, 123, 'Normal', 350],
        ['E002', 'F', 40, 114, 'Overweight', 450],
        ['E003', 'F', 37, 135, 'Obesity', 169],
        ['E004', 'M', 30, 139, 'Underweight', 189],
        ['E005', 'F', 44, 117, 'Underweight', 183],
        ['E006', 'M', 36, 121, 'Normal', 80],
        ['E007', 'M', 32, 133, 'Obesity', 166],
        ['E008', 'F', 26, 140, 'Normal', 120],
        ['E009', 'M', 32, 133, 'Normal', 75],
        ['E010', 'M', 36, 133, 'Underweight', 40] ]
 
# dataframe created with
# the above data array
df = pd.DataFrame(data, columns = ['EMPID', 'Gender', 
                                    'Age', 'Sales',
                                    'BMI', 'Income'] )
 
# create histogram for numeric data
df.hist()
 
# show plot
mp.show()

# %%
mp.pie(df['Age'], labels = {"A", "B", "C", 
                            "D", "E", "F", 
                            "G", "H", "I", "J"}, 
                             
autopct ='% 1.1f %%', shadow = True) 
mp.show() 
 
mp.pie(df['Income'], labels = {"A", "B", "C", 
                                "D", "E", "F", 
                                "G", "H", "I", "J"}, 
                                 
autopct ='% 1.1f %%', shadow = True) 
mp.show() 
 
mp.pie(df['Sales'], labels = {"A", "B", "C", 
                            "D", "E", "F", 
                            "G", "H", "I", "J"}, 
autopct ='% 1.1f %%', shadow = True) 
mp.show()

# %%
import this

# %%
pip install seaborn

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as mp
# Example: Heatmap
data = np.random.rand(10, 12)
sns.heatmap(data, cmap='viridis')
mp.title('Heatmap Example')
mp.show()
